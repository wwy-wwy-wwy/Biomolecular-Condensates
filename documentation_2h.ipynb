# %% [markdown]
# # Team members:
# Anqi Chen, Wenyun Wang, Hanyue Wang

# %% [markdown]
# # References:
# - "Time Series Analysis with Applications in R" by Jonathan D. Cryer and Kung-Sik Chan
#
# - https://docs.pymc.io/en/v3/pymc-examples/examples/time_series/AR.html
#
# - https://en.wikipedia.org/wiki/Autoregressive_model

# %%
import condensate_speckle
from condensate_speckle.data_io import*
from condensate_speckle.inference.model import*
from condensate_speckle.inference.simulation import *
# Out:
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
# /Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
import numpy as np
from matplotlib import pyplot as plt
import pymc3 as pm
import arviz as az
import statsmodels.api as sm
import csv

# %%
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 10787
np.random.seed(RANDOM_SEED)
az.style.use("arviz-darkgrid")

# %% [markdown]
# # General model & simulating data

# %% [markdown]
# We are using first order autoregression model as our general model. The overal general form of autoregression model is $Y_t=\sum_{i=1}^{p}\phi_i\times Y_{t-i}+e_t$, where $Y$ is the intensity at each time point, $\phi_i$ is the decay parameter that depends on $\tau$, and $e_t$ is the innovation term. For this project, we are using first-order approximation only, known as AR(1) model. That is $$Y_t=\phi\times Y_{t-1}+e_t$$
# , where $\phi=\exp(-1/\tau)$. So the equation becomes $Y_t=\exp(-1/\tau)\times Y_{t-1}+e_t$.
#
# We need to specify three variables in order to build the generative model: the mean $c$ and standard deviation $\sigma_e$ of the innovation term $e_t$, and decay time $\tau$. Here, $e_t$ is considered as Gaussian distribution and $\tau$ is the value that we are most interested in. We also need the distribution noise level of microscope, which is assumed to be a Normal distribution as well.
#
# From the model, the overall data intensity mean can be calculated by $\frac{c}{1-\phi}$ and the intensity variance is $\frac{\sigma_e^2}{1-\phi^2}$.

# %% [markdown]
# ## simulate single time scale

# %%
number_of_points=5000
tau=10
quantization=255
intensity_mean=80
intensity_std=20
camera_noise=5
camera_std=1

# %%
simulated_data_single, simulated_t_single=simulate_single_decay_data(number_of_points,tau, quantization, intensity_mean, intensity_std, camera_noise, camera_std)

# %% [markdown]
# ## simulate 2 time scales

# %%
number_of_points=5000
tau_1=3
tau_2=300
relative_var=0.5
quantization=255
intensity_mean=80
intensity_std=40
camera_noise=8
camera_std=3

# %%
simulated_data_double, simulated_t_double=simulate_double_decay_data(number_of_points,tau_1,tau_2, relative_var,quantization, intensity_mean, intensity_std, camera_noise, camera_std)

# %% [markdown]
# # Load in real data

# %%
# Load in data
X = load_data('[150, 9]_2h_intensity.csv',data_dir='condensate_speckle/example_data').to_numpy()
data_pds={'t':X[0],'Intensity':X[1]}
dataframe=pd.DataFrame(data=data_pds)
quantization = 255
# Out:
# /Users/wenyun/Documents/GitHub/Condensate_speckles/condensate_speckle/example_data/[150, 9]_2h_intensity.csv

# %%
plt.plot(dataframe['t'],dataframe['Intensity'])

# %% [markdown]
# # Infer decay time from data using the AR(1) model in pymc3

# %% [markdown]
# To fit our model AR1 model, we want to extract the following parameters: decay time, which is the $\tau$ above; stationary is the $\phi$, precision is defined as $\frac{1}{\sigma_e^2}$; center is the innovation mean. Our prior for $\tau$ is uniform from 0 to 50, based on the experimental data time scale; for precision, we also use a uniform prior from 0 to 10 times the calculated precision from simulation parameters; for center, it is uniform from the lowest possible intensity to the highest possible intensity.
#
# Thus, the statistical model we use is:
# $$ \tau \sim \text{Uniform} (0,50) $$
# $$ \text{precision} \sim \text{Uniform} (0, 1) $$
# $$ \mu \sim \text{Uniform} (I_{min}, I_{max}) $$
# $$ p(X) \sim \text{AR1} (\text{k} = e^{-1/\tau}, \text{tau_e} = \text{precision}, \text{observed} = X-\mu )$$

# %%
# Define ar1 model
ar1_model=set_model(dataframe['Intensity'],quantization)

# %%
# Run sampling to infer the MAP and uncertainty of the decay time
with ar1_model:
    trace = pm.sample(1000, tune=2000, init="advi+adapt_diag", random_seed=RANDOM_SEED)
    idata = az.from_pymc3(trace)
# Out:
# /var/folders/wf/qxrbnsmd4xn7cplm95fm264w0000gn/T/ipykernel_10135/3990096818.py:3: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(1000, tune=2000, init="advi+adapt_diag", random_seed=RANDOM_SEED)
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='60940' class='' max='200000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.47% [60940/200000 00:08<00:19 Average Loss = 1,193]
#     </div>
# Convergence achieved at 61100
# Interrupted at 61,099 [30%]: Average Loss = 2,025.3
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [y, noise_std, precision, decay_time]
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
# Traceback (most recent call last):
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/forkserver.py", line 274, in main
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/forkserver.py", line 313, in _serve_one
#     code = spawn._main(child_r, parent_sentinel)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/__init__.py", line 23, in <module>
#     import theano
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/__init__.py", line 66, in <module>
#     from theano.configdefaults import config
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/configdefaults.py", line 11, in <module>
#     import numpy as np
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/numpy/__init__.py", line 155, in <module>
#     from . import random
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/numpy/random/__init__.py", line 180, in <module>
#     from . import _pickle
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/numpy/random/_pickle.py", line 1, in <module>
#     from .mtrand import RandomState
#   File "mtrand.pyx", line 1, in init numpy.random.mtrand
# ImportError: dlopen(/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/numpy/random/bit_generator.cpython-39-darwin.so, 2): no suitable image found.  Did find:
# 	/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/numpy/random/bit_generator.cpython-39-darwin.so: open() failed with errno=23
# Process worker_chain_0:
# Traceback (most recent call last):
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py", line 116, in _unpickle_step_method
#     self._step_method = pickle.loads(self._step_method)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/compile/function/types.py", line 1165, in _constructor_Function
#     f = maker.create(input_storage, trustme=True)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/compile/function/types.py", line 1836, in create
#     _fn, _i, _o = self.linker.make_thunk(
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/basic.py", line 266, in make_thunk
#     return self.make_all(
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/vm.py", line 1131, in make_all
#     node.op.make_thunk(node, storage_map, compute_map, [], impl=impl)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/c/basic.py", line 48, in get_module_cache
#     return _get_module_cache(config.compiledir, init_args=init_args)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1595, in get_module_cache
#     _module_cache = ModuleCache(dirname, **init_args)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 683, in __init__
#     self.refresh()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 773, in refresh
#     files = os.listdir(root)
# OSError: [Errno 23] Too many open files in system: '/Users/wenyun/.theano/compiledir_macOS-11.2-x86_64-i386-64bit-i386-3.9.9-64/tmp8w26oa5u'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py", line 135, in run
#     self._unpickle_step_method()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py", line 118, in _unpickle_step_method
#     raise ValueError(unpickle_error)
# ValueError: The model could not be unpickled. This is required for sampling with more than one core and multiprocessing context spawn or forkserver.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py", line 230, in _run_process
#     _Process(*args).run()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py", line 145, in run
#     self._wait_for_abortion()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py", line 151, in _wait_for_abortion
#     msg = self._recv_msg()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py", line 169, in _recv_msg
#     return self._msg_pipe.recv()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/connection.py", line 388, in _recv
#     raise EOFError
# EOFError
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# Input In [7], in <module>
#       1 # Run sampling to infer the MAP and uncertainty of the decay time
#       2 with ar1_model:
# ----> 3     trace = pm.sample(1000, tune=2000, init="advi+adapt_diag", random_seed=RANDOM_SEED)
#       4     idata = az.from_pymc3(trace)
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/sampling.py:559, in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, pickle_backend, **kwargs)
#     557 _print_step_hierarchy(step)
#     558 try:
# --> 559     trace = _mp_sample(**sample_args, **parallel_args)
#     560 except pickle.PickleError:
#     561     _log.warning("Could not pickle model, sampling singlethreaded.")
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/sampling.py:1461, in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, callback, discard_tuned_samples, mp_ctx, pickle_backend, **kwargs)
#    1458         strace.setup(draws + tune, idx + chain)
#    1459     traces.append(strace)
# -> 1461 sampler = ps.ParallelSampler(
#    1462     draws,
#    1463     tune,
#    1464     chains,
#    1465     cores,
#    1466     random_seed,
#    1467     start,
#    1468     step,
#    1469     chain,
#    1470     progressbar,
#    1471     mp_ctx=mp_ctx,
#    1472     pickle_backend=pickle_backend,
#    1473 )
#    1474 try:
#    1475     try:
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py:431, in ParallelSampler.__init__(self, draws, tune, chains, cores, seeds, start_points, step_method, start_chain_num, progressbar, mp_ctx, pickle_backend)
#     428             raise ValueError("dill must be installed for pickle_backend='dill'.")
#     429         step_method_pickled = dill.dumps(step_method, protocol=-1)
# --> 431 self._samplers = [
#     432     ProcessAdapter(
#     433         draws,
#     434         tune,
#     435         step_method,
#     436         step_method_pickled,
#     437         chain + start_chain_num,
#     438         seed,
#     439         start,
#     440         mp_ctx,
#     441         pickle_backend,
#     442     )
#     443     for chain, seed, start in zip(range(chains), seeds, start_points)
#     444 ]
#     446 self._inactive = self._samplers.copy()
#     447 self._finished = []
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py:432, in <listcomp>(.0)
#     428             raise ValueError("dill must be installed for pickle_backend='dill'.")
#     429         step_method_pickled = dill.dumps(step_method, protocol=-1)
#     431 self._samplers = [
# --> 432     ProcessAdapter(
#     433         draws,
#     434         tune,
#     435         step_method,
#     436         step_method_pickled,
#     437         chain + start_chain_num,
#     438         seed,
#     439         start,
#     440         mp_ctx,
#     441         pickle_backend,
#     442     )
#     443     for chain, seed, start in zip(range(chains), seeds, start_points)
#     444 ]
#     446 self._inactive = self._samplers.copy()
#     447 self._finished = []
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/pymc3/parallel_sampling.py:292, in ProcessAdapter.__init__(self, draws, tune, step_method, step_method_pickled, chain, seed, start, mp_ctx, pickle_backend)
#     274     step_method_send = step_method
#     276 self._process = mp_ctx.Process(
#     277     daemon=True,
#     278     name=process_name,
#    (...)
#     290     ),
#     291 )
# --> 292 self._process.start()
#     293 # Close the remote pipe, so that we get notified if the other
#     294 # end is closed.
#     295 remote_conn.close()
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/context.py:291, in ForkServerProcess._Popen(process_obj)
#     288 @staticmethod
#     289 def _Popen(process_obj):
#     290     from .popen_forkserver import Popen
# --> 291     return Popen(process_obj)
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/popen_forkserver.py:35, in Popen.__init__(self, process_obj)
#      33 def __init__(self, process_obj):
#      34     self._fds = []
# ---> 35     super().__init__(process_obj)
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File ~/opt/anaconda3/envs/phys201/lib/python3.9/multiprocessing/popen_forkserver.py:58, in Popen._launch(self, process_obj)
#      55 self.finalizer = util.Finalize(self, util.close_fds,
#      56                                (_parent_w, self.sentinel))
#      57 with open(w, 'wb', closefd=True) as f:
# ---> 58     f.write(buf.getbuffer())
#      59 self.pid = forkserver.read_signed(self.sentinel)
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
az.plot_trace(
    trace,
    var_names = ['decay_time','precision','noise_std'],
);

# %% [markdown]
# # Infer decay time from data using the 2*AR(1) model in pymc3

# %%
ar1_multi_model=set_double_scale_model(dataframe['Intensity'], quantization)

# %%
with ar1_multi_model:
    trace = pm.sample(1000, tune=2000, init="advi+adapt_diag", random_seed=RANDOM_SEED)
    idata = az.from_pymc3(trace)
# Out:
# /var/folders/wf/qxrbnsmd4xn7cplm95fm264w0000gn/T/ipykernel_6780/1357765701.py:2: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(1000, tune=2000, init="advi+adapt_diag", random_seed=RANDOM_SEED)
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200000' class='' max='200000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200000/200000 00:48<00:00 Average Loss = 3,705.6]
#     </div>
# Finished [100%]: Average Loss = 3,705.6
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [y2, y1, noise_std, precision_2, precision_1, decay_time_split, decay_time_1]
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 02:11<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 2_000 tune and 1_000 draw iterations (8_000 + 4_000 draws total) took 144 seconds.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
az.plot_trace(
    trace,
    var_names =['decay_time_1', 'decay_time_2', 'precision_1', 'precision_2'],
);
# Out:
# /Users/wenyun/opt/anaconda3/envs/phys201/lib/python3.9/site-packages/arviz/data/io_pymc3.py:96: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
